# %%
# !pip install -U pip transformers
# Out:
# Requirement already satisfied: pip in /usr/local/lib/python3.12/dist-packages (24.1.2)
# Collecting pip
#   Downloading pip-25.2-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (4.56.2)
# Collecting transformers
#   Downloading transformers-4.57.0-py3-none-any.whl.metadata (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.4/41.4 kB 3.0 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers) (3.19.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.35.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.6.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2025.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (1.1.10)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2025.8.3)
# Downloading pip-25.2-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 27.2 MB/s eta 0:00:00
# Downloading transformers-4.57.0-py3-none-any.whl (12.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 48.3 MB/s eta 0:00:00
# Installing collected packages: pip, transformers
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.56.2
#     Uninstalling transformers-4.56.2:
#       Successfully uninstalled transformers-4.56.2
# Successfully installed pip-25.2 transformers-4.57.0

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

# %%
checkpoint = 'facebook/nllb-200-distilled-600M'
tokenizer = AutoTokenizer.from_pretrained(checkpoint)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/564 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/4.85M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.3M [00:00<?, ?B/s]
# special_tokens_map.json: 0.00B [00:00, ?B/s]

# %%
print(f"{len(tokenizer.vocab)}\n")

tokenizer.vocab
# Out:
# 256204
# {'▁ਕੀਤੇ': 59485,
#  '▁beza': 67932,
#  '▁स्रोत': 82836,
#  '▁nødvendig': 60764,
#  '▁Iyan': 76459,
#  '▁ต้อง': 95143,
#  'ระหว่าง': 118360,
#  '▁მოვლ': 227111,
#  'زم': 10982,
#  '▁ਹੱਕ': 240779,
#  '▁ਉੱਤੇ': 44108,
#  '▁fratello': 149899,
#  '▁bunda': 130454,
#  'திகள்': 136042,
#  'fij_Latn': 256054,
#  '▁لمس': 163571,
#  'ючи': 16553,
#  '▁after': 16616,
#  '▁Tungod': 82764,
#  'ەندىكى': 192263,
#  'կն': 125697,
#  '▁wakula': 191426,
#  '▁હંમેશા': 71916,
#  '▁whakamar': 180666,
#  '▁kesel': 56374,
#  'ဟန်': 241294,
#  '▁aggód': 213559,
#  '▁cú': 34447,
#  '▁အိမ်': 67111,
#  'akampi': 152930,
#  '▁Voki': 100367,
#  '▁консул': 229207,
#  '▁ମାନଙ୍କୁ': 242499,
#  '▁temperatura': 57008,
#  '▁makhetlo': 189099,
#  'umot': 225486,
#  'omb': 1588,
#  '▁마지막': 28280,
#  'кинг': 226160,
#  '▁fore': 38249,
#  '▁итте': 46158,
#  '▁제발': 167481,
#  'çanërisht': 189903,
#  '內': 251948,
#  '잖': 251520,
#  'GS': 78104,
#  '▁ଖୁବ': 85036,
#  'qot': 93776,
#  '▁Arri': 205086,
#  'ほん': 67583,
#  'それぞれの': 97717,
#  'леж': 78336,
#  '▁Ñe': 133032,
#  '▁omkring': 43735,
#  '目的': 21144,
#  '▁kajeno': 79829,
#  '▁уақытша': 181997,
#  '▁Nkhani': 83415,
#  'ราย': 80370,
#  'zać': 75885,
#  'ilay': 24480,
#  '▁ಶಾಲೆ': 163115,
#  '佳': 253213,
#  '▁שאמר': 181945,
#  '▁요': 8111,
#  '▁לעבור': 203997,
#  'andĩkonĩ': 127136,
#  '▁បោះ': 220660,
#  'undo': 10583,
#  'upaya': 237395,
#  '罪を': 106007,
#  'ələ': 38138,
#  '▁ହେଇ': 126741,
#  '▁صحت': 82752,
#  '▁koki': 42216,
#  '▁sealladh': 218410,
#  '▁Ziele': 205904,
#  '▁aizsardzību': 205965,
#  '▁hi': 435,
#  '▁berdoa': 156203,
#  'akunda': 229323,
#  '▁утица': 115878,
#  'බ': 249178,
#  '▁tas': 2626,
#  '▁сві': 13242,
#  '▁produktas': 217389,
#  'anyana': 46100,
#  '▁math': 12443,
#  '▁kajian': 105017,
#  '▁vertu': 200066,
#  'མིན་': 55142,
#  '▁စမ်း': 141327,
#  'llahu': 68889,
#  '使你们': 134735,
#  '▁mosa': 69031,
#  '▁अउर': 4102,
#  '▁dic': 18346,
#  '玛': 253282,
#  '▁পরবর্তী': 202817,
#  'pif': 199086,
#  'тір': 238183,
#  '大幅': 141517,
#  '֙': 254980,
#  'хвър': 127058,
#  '▁kormány': 75547,
#  '▁visst': 148065,
#  '▁ezinkulu': 123872,
#  '▁farko': 30899,
#  '▁άλλους': 157541,
#  '▁lõpet': 83374,
#  '▁Medlemsstaterna': 230199,
#  '▁lands': 54829,
#  '▁primera': 27340,
#  'oco': 100351,
#  '▁жете': 133558,
#  '▁Kno': 140633,
#  '▁PUWANG': 77884,
#  '▁tëk': 161135,
#  '▁প্রক্রিয়া': 188774,
#  '▁apan': 22427,
#  'имо': 79501,
#  '▁cognos': 110294,
#  '▁akha': 211858,
#  '▁proċedura': 139636,
#  'влива': 219473,
#  'akat': 3034,
#  'osan': 10049,
#  'orsz': 37110,
#  '▁האור': 230629,
#  '▁masyarakat': 33414,
#  '▁onjo': 175897,
#  '▁ạ': 127442,
#  '▁mwaba': 201135,
#  'ayensi': 110980,
#  'seas': 220312,
#  '▁කෙන': 40128,
#  'amul': 207253,
#  'גער': 102058,
#  '▁Miz': 83878,
#  '这个': 62789,
#  '▁diro': 171561,
#  'éget': 144296,
#  '▁అంగీకరించ': 243290,
#  '▁ча': 3098,
#  '▁ndambu': 144849,
#  'を知っている': 93194,
#  '▁rent': 40620,
#  'बितर': 205215,
#  'мірі': 93755,
#  'дея': 174321,
#  '▁ತಲುಪ': 148301,
#  '▁የለን': 235824,
#  '▁ପାଖ': 48840,
#  '▁хоро': 33797,
#  '▁kaluluwa': 233409,
#  '▁Sime': 74335,
#  '▁tr': 296,
#  'obuk': 228134,
#  '▁shit': 54613,
#  '▁ማለት': 26433,
#  '▁sesĩe': 181310,
#  '▁2004/3': 209116,
#  '▁utj': 37605,
#  '▁yɛbɔ': 214830,
#  '▁botës': 125289,
#  'izwi': 111657,
#  '▁nesa': 18529,
#  '▁tingimused': 213196,
#  '井': 253023,
#  '▁Tir': 28215,
#  '運営': 88223,
#  '▁momo': 22245,
#  'fiden': 224093,
#  '▁mannen': 63779,
#  '▁Schmid': 197692,
#  '▁તને': 112898,
#  '▁위한': 15330,
#  'شتہ': 100387,
#  '▁tlhak': 215418,
#  'の場合': 109517,
#  '▁uccider': 242136,
#  '▁wagyzçy': 232160,
#  '▁присвя': 220253,
#  '▁nakɛyɛ': 163690,
#  'нони': 97106,
#  '▁स्पी': 241354,
#  '▁ҡарағанда': 163406,
#  '▁nedaudz': 141998,
#  '▁ବିଶ୍ୱର': 231478,
#  '▁Won': 61507,
#  '▁prišlo': 199181,
#  '▁위협': 62297,
#  '▁12:5': 209194,
#  '▁Claude': 183220,
#  'قع': 21793,
#  '▁Πες': 143300,
#  '▁herri': 163905,
#  '▁Os': 5371,
#  '▁рөх': 103053,
#  '▁owad': 172948,
#  'wasz': 233444,
#  '▁γεωργ': 229971,
#  '▁mɔzɔ': 226763,
#  '▁cuda': 206144,
#  '▁goob': 233324,
#  '▁الوقت': 49514,
#  '▁jedným': 153762,
#  '▁ଆମକୁ': 111601,
#  '▁pɩnzɩ': 112101,
#  'byt': 79089,
#  '▁akaun': 130184,
#  '▁vozilo': 238482,
#  '▁են': 5109,
#  'かり': 14501,
#  'ಿಯ': 3431,
#  '▁ንም': 31465,
#  '▁ọnụ': 29352,
#  '浅': 254317,
#  '▁clairement': 244407,
#  '▁maru': 136651,
#  '▁العاده': 121681,
#  'ämme': 42247,
#  '▁konsep': 61745,
#  'företag': 125295,
#  '밀': 251012,
#  'ganap': 210649,
#  '▁psiholo': 207340,
#  '▁מחפ': 228468,
#  '▁zĩnda': 244171,
#  '▁ért': 19082,
#  '▁pich': 217785,
#  '▁Datum': 204481,
#  '▁lắng': 89254,
#  '▁ဖြစ်ပါတယ်။': 167568,
#  'opito': 165633,
#  '▁bua': 3536,
#  '▁कोही': 127037,
#  '▁filmas': 175383,
#  '▁кух': 165304,
#  'ཚ': 248887,
#  '▁देह': 93462,
#  '▁săn': 141668,
#  '▁समिति': 122131,
#  '▁mechan': 91397,
#  'ೂಹ': 204921,
#  '답니다': 100173,
#  'odadh': 86918,
#  '▁अनंत': 202487,
#  '▁ξ': 10243,
#  '▁пів': 122329,
#  '▁1969,': 211350,
#  '▁dipotso': 137510,
#  '▁ninsaal': 71286,
#  'ψουμε': 178202,
#  '༠༠༠': 203681,
#  'ミック': 235155,
#  '▁tutar': 193126,
#  '▁sukan': 151944,
#  'アルバ': 76384,
#  '▁Feumaidh': 121162,
#  'zais': 198643,
#  '▁tiamisila': 136852,
#  'жок': 207104,
#  'ੁਕਤ': 151759,
#  '▁Било': 179536,
#  '▁degan': 61180,
#  '紳': 255226,
#  '▁koŋ': 93230,
#  '▁piedra': 211262,
#  '▁захоп': 184074,
#  '▁देखिए': 228544,
#  'eq': 142073,
#  'ą': 248587,
#  '▁ମଧ୍ୟ': 10144,
#  'ಿಸಲಾಯಿತು': 160019,
#  '▁विवा': 212844,
#  '世界的な': 197194,
#  '▁의도': 140740,
#  '▁இங்க': 126664,
#  '당한': 87603,
#  '▁ýere': 151370,
#  '▁viime': 54920,
#  '▁domstolen': 211406,
#  '▁çag': 95416,
#  'okrasi': 140260,
#  '▁geë': 167405,
#  '▁production': 49007,
#  'пайым': 191802,
#  '▁Quinn': 194213,
#  '▁thoải': 171657,
#  '▁publica': 49785,
#  '▁avait': 26705,
#  'វា': 49628,
#  '▁rahina': 60911,
#  'غب': 115311,
#  '▁произ': 13366,
#  '▁무서워': 214816,
#  'φορά': 37014,
#  '▁marš': 140149,
#  '▁plats': 94704,
#  'lhanka': 80963,
#  'fft': 36759,
#  '▁자들': 221504,
#  'ໄທ': 198745,
#  'worthy': 154143,
#  'uraya': 98042,
#  'сэн': 8842,
#  '[4': 70706,
#  '▁بخير': 107180,
#  'ሓ': 249383,
#  '▁Re': 1420,
#  '▁anọ': 53988,
#  'sey': 29595,
#  'umų': 168580,
#  '▁автомобиль': 118896,
#  '▁समयमा': 113156,
#  '▁Gig': 148169,
#  '▁судо': 242787,
#  'անքը': 218156,
#  'കരണ': 142327,
#  '▁Rock': 49255,
#  'مەن': 15429,
#  '見解': 143052,
#  '▁û': 7593,
#  '▁tager': 59974,
#  '▁맞아': 213368,
#  '▁ndaa': 148406,
#  '▁знову': 102149,
#  '▁kontrole': 146915,
#  'cla': 48768,
#  '▁jeto': 129729,
#  '▁poeta': 174089,
#  '▁Kadangi': 164241,
#  'していきます': 152543,
#  '▁Mats': 41390,
#  '▁gjendje': 120192,
#  '▁دواتر': 85966,
#  '▁ente': 14042,
#  '▁Yıl': 223295,
#  '▁verske': 130462,
#  '▁ကို': 7911,
#  '▁ఆహ': 77805,
#  '▁dra': 5614,
#  '▁stresu': 243621,
#  '▁fapt': 62814,
#  '▁ਕੰਪ': 77531,
#  'wendung': 68262,
#  '▁brænd': 175189,
#  'ალიზ': 244643,
#  '▁Слова': 211623,
#  'גרת': 223738,
#  'უშ': 35345,
#  '▁nafsu': 242631,
#  'ского': 23949,
#  '光の': 243881,
#  '▁Mukanda': 100314,
#  '▁ဧ': 96497,
#  '切り': 57846,
#  'ស': 248745,
#  '▁হতা': 221251,
#  'と言った': 60083,
#  '▁utgjør': 233541,
#  '▁Enoke': 221550,
#  '▁그녀와': 219020,
#  '▁নাজ': 139490,
#  '▁വൃ': 196840,
#  '▁rime': 111770,
#  '▁ⵜⵖ': 167754,
#  '▁thinks': 168796,
#  'aseen': 241497,
#  'Im': 40829,
#  '▁keis': 219044,
#  '👍': 253416,
#  'catu': 149109,
#  '▁kombela': 78938,
#  'ốn': 9180,
#  '▁студије': 221463,
#  '依家': 248008,
#  'ཤུལ་སྦེ་': 148693,
#  '괴': 251339,
#  '▁nimetatud': 84587,
#  '▁iespēja': 89010,
#  'ấng': 119822,
#  '▁ਪੂਰ': 138992,
#  '▁σα': 84456,
#  '▁gilt': 104458,
#  '▁promluvit': 231514,
#  'ılar': 25073,
#  '▁خطأ': 233457,
#  '▁것이라는': 107409,
#  '株': 252282,
#  '▁use': 11007,
#  'ંતી': 231540,
#  'アム': 196830,
#  '▁ଆକାଉ': 247881,
#  'κλη': 67850,
#  'ण्याची': 47832,
#  'என': 206097,
#  '▁säger': 61942,
#  '▁pae': 65668,
#  '▁گیا۔': 169584,
#  'Babil': 157711,
#  '▁бір': 9955,
#  '▁प्रस्ताव': 65885,
#  '壮': 253691,
#  'arsa': 43145,
#  '▁dagi': 177540,
#  '▁Apr': 15461,
#  '▁ཐ': 18013,
#  '▁tengen': 183909,
#  '▁deungoe': 101535,
#  '▁آشنا': 168102,
#  '▁پلا': 97304,
#  '▁tunggu': 56667,
#  '▁feite': 209488,
#  '▁अली': 172841,
#  '▁অন্য': 21722,
#  'ታችንን': 234641,
#  '▁mawudɔ': 170035,
#  '▁ಎ': 3238,
#  '▁bhua': 60178,
#  '▁ndihmon': 186829,
#  '▁Moapostola': 156486,
#  '▁แล้วก็': 162226,
#  '▁dzēri': 219208,
#  'size': 225340,
#  '▁mejeeji': 223065,
#  '心臓': 132247,
#  '▁sila': 7174,
#  '▁ivy': 49041,
#  'தற்கு': 165719,
#  '▁tarp': 33457,
#  '▁формула': 225931,
#  '▁poxolo': 109568,
#  '▁attemp': 133610,
#  '▁Tiang': 31230,
#  'тимо': 117625,
#  '細胞': 54510,
#  '▁Kosovë': 200668,
#  '▁sị': 19313,
#  'samling': 188530,
#  '▁vavasati': 100263,
#  'す': 248334,
#  '요일': 42533,
#  'alagad': 79898,
#  '▁arwain': 143988,
#  '▁bengi': 184699,
#  '▁словам': 219395,
#  'vaná': 238548,
#  'heur': 150473,
#  '▁rozt': 145297,
#  '▁kuj': 15728,
#  '▁inspektor': 247579,
#  'نجى': 183363,
#  'xi': 1678,
#  '▁långt': 179282,
#  '▁беру': 14938,
#  '▁سلی': 144697,
#  '▁ಸುಲಭ': 98387,
#  '▁લોકો': 16390,
#  'esday': 169562,
#  'ampaikan': 103722,
#  '▁tango': 60013,
#  'thá': 198966,
#  '▁Dou': 27138,
#  '▁실수': 125587,
#  '▁استعداد': 200208,
#  '▁klik': 47221,
#  'nī': 24535,
#  'েম': 39260,
#  '▁acting': 188121,
#  '▁britiske': 126247,
#  '▁mengharapkan': 179314,
#  '▁gbádùn': 167450,
#  '▁خەۋ': 55819,
#  '▁awe': 24089,
#  'allisten': 227154,
#  '▁ဘယ်လို': 52735,
#  'གྱ': 3133,
#  'Jehovha': 29325,
#  '▁portal': 106104,
#  '▁رت': 80435,
#  '▁Umwami': 125477,
#  '▁przy': 9471,
#  'वाणी': 164904,
#  'fli': 26168,
#  '15.': 237846,
#  'を強化': 179986,
#  '▁Хоча': 143582,
#  '▁karakter': 24292,
#  'ママ': 208521,
#  'chii': 124848,
#  '▁nayat': 91777,
#  '▁kvaliteten': 189469,
#  '▁hamavu': 94175,
#  '▁Syria': 49486,
#  '栄養': 119266,
#  '▁majbur': 244014,
#  '▁သိုၵ်း': 235756,
#  '▁відомий': 247196,
#  '▁Itu': 27266,
#  '▁Sà': 200819,
#  '▁ficar': 59745,
#  '▁kwĩkala': 76776,
#  'ināja': 68605,
#  '▁ቅድ': 43808,
#  'ларҙы': 87547,
#  '▁нәкъ': 244317,
#  'タンパク質': 161676,
#  '▁kdaj': 96745,
#  '园': 252387,
#  '▁Semu': 132457,
#  '▁ረ': 33054,
#  '▁38%': 233627,
#  '▁ᱜᱮ': 151010,
#  '時間で': 188913,
#  '▁Stahl': 236587,
#  '야': 249118,
#  'pomín': 217774,
#  'ЕТ': 216540,
#  'uws': 157691,
#  '▁αποτέλεσμα': 226548,
#  '▁практи': 29448,
#  'க': 248273,
#  '▁кора': 53896,
#  '▁дапа': 114846,
#  '▁colocar': 211772,
#  'rd': 9262,
#  '▁Count': 184351,
#  '▁cw': 55006,
#  'クラス': 103575,
#  'យោ': 69321,
#  '▁ndat': 124913,
#  '▁কাৰ্য': 78411,
#  'vyabona': 114568,
#  '▁គ': 5253,
#  'oub': 206326,
#  '▁soa': 64696,
#  '▁говорили': 148376,
#  'hella': 201104,
#  '▁trods': 170666,
#  '▁membuat': 11179,
#  '▁elfogad': 83123,
#  '▁eheyi': 113391,
#  '▁idee': 44103,
#  'íku': 156849,
#  'čiai': 36217,
#  '▁massive': 209532,
#  'ҡи': 85637,
#  'বে': 2179,
#  '▁محدود': 36612,
#  'በኣ': 140178,
#  '▁министрлігінің': 127610,
#  '市场': 224043,
#  '▁ያስ': 41733,
#  '▁uitdag': 156964,
#  'ོལ་ལ': 123799,
#  '▁મોટો': 182132,
#  '▁mwal': 153108,
#  '消失': 201554,
#  '▁pratiques': 237189,
#  '▁ಅನುಮ': 126998,
#  '▁Ondo': 116309,
#  '年前に': 102799,
#  'ćete': 110717,
#  'qali': 44230,
#  '▁ngosi': 133917,
#  '္ဂ': 61672,
#  'ක්ක': 20887,
#  '▁дође': 196334,
#  '▁yidhi': 33094,
#  '▁semoga': 88786,
#  '▁tongaso': 42166,
#  'likia': 137094,
#  'ఫల': 216278,
#  '▁vonjo': 204492,
#  '▁full': 14577,
#  'emesha': 169320,
#  '▁Pana': 41424,
#  '▁won': 7473,
#  '▁Jesú': 144964,
#  '▁Har': 4187,
#  '▁ତାହାର': 194341,
#  'করা': 191982,
#  '▁बनि': 122491,
#  'ұлға': 39508,
#  'ãi': 10697,
#  '▁Ray': 30332,
#  '▁keletą': 155469,
#  'མ་ཤིང་': 191721,
#  '▁mtanda': 153209,
#  '▁ketat': 151875,
#  'कर्': 16323,
#  '▁dzavo': 158569,
#  '▁gruppen': 152161,
#  '▁нього': 71512,
#  '▁አያ': 73642,
#  '▁Kiristiya': 108466,
#  '▁limiti': 182449,
#  'カン': 78226,
#  'ismu': 47805,
#  '▁berde': 92488,
#  '▁anul': 154943,
#  '▁wutar': 242261,
#  '▁viespiritu': 164956,
#  '▁rendelkezik': 152241,
#  '▁atid': 155626,
#  '▁družba': 209243,
#  'ház': 90822,
#  '▁ರೂಪ': 117539,
#  'jamų': 183865,
#  '▁cymorth': 164087,
#  '▁qhis': 68955,
#  '▁చెప్పిన': 123027,
#  '▁وغير': 220532,
#  '▁pige': 172412,
#  '[1],[2].': 66906,
#  'emýš': 159954,
#  '▁dogara': 132665,
#  '▁tship': 159436,
#  'निक': 95561,
#  '▁வ': 1348,
#  '▁tighinn': 141128,
#  '▁vznik': 124286,
#  'เยี่ยม': 217476,
#  '▁elektroni': 245889,
#  'xió': 242909,
#  'お父': 197855,
#  '▁bint': 197894,
#  '▁defender': 189288,
#  '▁эми': 39838,
#  '▁ପଛରେ': 206014,
#  'ሉን': 71529,
#  '▁gany': 163286,
#  'tengo': 137540,
#  '▁ஆ': 4211,
#  'uiwa': 19507,
#  '▁tart': 15032,
#  '▁Atlas': 193468,
#  '▁zubha': 101290,
#  'aplica': 108926,
#  'ụàjà': 189615,
#  '▁Raad': 38518,
#  '▁kabayi': 110204,
#  'lalo': 22494,
#  'astes': 91719,
#  '▁tukar': 94003,
#  '▁priliku': 213032,
#  'တွေက': 31638,
#  '▁ủy': 247815,
#  'B': 248158,
#  'cze': 14520,
#  'gamot': 227383,
#  '쳤다': 106845,
#  'oue': 156848,
#  'িয়েই': 197778,
#  '▁Република': 118662,
#  '▁kartus': 171584,
#  '▁Uffiċjali': 218276,
#  '▁ud': 2482,
#  '▁też': 42153,
#  'ksk': 161643,
#  '▁ekteskap': 211934,
#  'ກາຍ': 96631,
#  '▁ترک': 65792,
#  'ssia': 126438,
#  '▁продукт': 130332,
#  '▁matunga': 240706,
#  '▁важи': 234510,
#  '▁neut': 36639,
#  '悅': 254359,
#  '▁сторо': 70968,
#  '▁μελών': 158892,
#  '▁sæt': 206885,
#  '▁bordet': 229841,
#  'AE': 50533,
#  'ၼိုင်ႈ': 95146,
#  '▁рік': 72900,
#  'yes': 15874,
#  'weuh': 164200,
#  '▁dirang': 49012,
#  '▁syy': 225671,
#  '▁bedrifter': 233577,
#  '▁Prad': 225372,
#  '▁yino': 203461,
#  '▁related': 93037,
#  'भार': 45336,
#  'ekarena': 218801,
#  '▁өндөр': 134225,
#  '▁horow': 109997,
#  '▁troppo': 72726,
#  '▁Pitts': 173142,
#  '▁kũndũ': 98171,
#  'larment': 140268,
#  '▁هیچی': 164139,
#  '▁vad': 7415,
#  '▁ფიქ': 104672,
#  '▁silakan': 197467,
#  'undisa': 171647,
#  '▁Jsus': 118421,
#  'バス': 98568,
#  'ৰিয়': 187604,
#  '▁σου': 9028,
#  '▁இயேசு': 117594,
#  '旅行': 42177,
#  '▁Mateu': 145174,
#  '▁बाहेर': 55629,
#  'ilere': 97333,
#  '▁يغ': 234966,
#  '▁stóð': 201851,
#  'si': 171,
#  'zamento': 209783,
#  '▁kalim': 85088,
#  '❚': 255819,
#  '▁sitwa': 208061,
#  '▁важни': 191932,
#  '▁kiny': 74226,
#  '▁turime': 109265,
#  'webo': 83637,
#  '▁جو': 2622,
#  '▁tít': 40766,
#  '▁przedsiębior': 129398,
#  '▁Pierɛ': 230287,
#  '▁سری': 95520,
#  '▁bakhe': 21851,
#  '▁cɔl': 23252,
#  '▁nyoe': 14000,
#  '想': 250090,
#  '▁chiwerengero': 182473,
#  '▁maş': 39115,
#  '很多': 157052,
#  '▁dintsi': 58751,
#  '▁광': 27921,
#  '▁yaku': 32742,
#  '▁fann': 40104,
#  '▁Yeremia': 91472,
#  '▁pipis': 92636,
#  '▁Mika': 45005,
#  'chite': 79304,
#  '▁चावल': 233844,
#  '▁धीरे': 128068,
#  '▁1933,': 234012,
#  '▁letla': 191064,
#  'то': 205,
#  '处': 251383,
#  'կար': 116534,
#  '▁Sebäbi': 102309,
#  '▁Kos': 20336,
#  '设施': 211954,
#  'ੈਂਟ': 161432,
#  '▁덧붙': 123245,
#  '▁Miten': 54985,
#  '▁beroep': 183637,
#  '▁צייַט': 115438,
#  'zött': 242194,
#  '▁അഞ്ച': 187222,
#  'お勧め': 193647,
#  '▁দলের': 152336,
#  '▁میڈیا': 211107,
#  '▁tumi': 34493,
#  'apit': 38520,
#  '▁ပြောင်း': 74426,
#  'ողական': 167431,
#  'hilom': 70367,
#  '들에게': 8085,
#  '▁maithe': 166258,
#  '▁masani': 36282,
#  '갇': 253716,
#  'guli': 146534,
#  '▁nyalana': 232158,
#  '▁හඳු': 194727,
#  'êm': 10218,
#  '▁megold': 82633,
#  '▁atimmu': 231643,
#  '▁Tengah': 116100,
#  '▁dua': 3825,
#  '▁ಸದ': 90913,
#  '▁pareng': 151453,
#  'allegato': 132768,
#  '▁Fisher': 183322,
#  'ined': 69059,
#  '▁dijinga': 120659,
#  'ahin': 142768,
#  '▁ξέρουμε': 224806,
#  '▁வாச': 213509,
#  'elnud': 145454,
#  '▁hestoria': 92078,
#  '▁соответ': 42152,
#  '採択': 183758,
#  'vèl': 145966,
#  '▁Cono': 191704,
#  'wierd': 103609,
#  '▁panui': 155770,
#  'மானது': 134154,
#  'եան': 58253,
#  '▁ଦ୍ବ': 95085,
#  'orë': 131149,
#  '▁procesas': 206835,
#  'eli': 4619,
#  '▁Igi': 38572,
#  '▁депута': 90756,
#  'ðà': 44073,
#  '▁રમ': 97327,
#  'akhulu': 186486,
#  'तया': 113586,
#  '▁agbanwe': 204138,
#  'ืด': 235971,
#  '▁futhi': 6572,
#  '▁lõpuks': 141225,
#  'క్య': 175510,
#  '▁sumaq': 163527,
#  '▁tautua': 179292,
#  'మాని': 196972,
#  '▁lef': 11810,
#  '▁bersamaan': 217555,
#  '発達': 182270,
#  '의를': 79871,
#  'artic': 39712,
#  'อ': 248523,
#  '▁sudaro': 81920,
#  'جه': 5882,
#  '៣': 251873,
#  '▁tseneletšego': 220757,
#  'nios': 56411,
#  '学习': 197281,
#  '沃': 253365,
#  '▁kucha': 156123,
#  'њу': 13587,
#  '▁flic': 217626,
#  'etuju': 60441,
#  '▁Persona': 140507,
#  '詛': 255357,
#  'চ': 248825,
#  'ოგორ': 15543,
#  '▁muutub': 225099,
#  '▁arva': 225207,
#  '▁៥': 110937,
#  'ປະຕິບັດ': 91065,
#  '▁වුනේ': 181749,
#  '▁Powell': 198152,
#  '▁hy': 4016,
#  '▁թագ': 111328,
#  'මිය': 243895,
#  '▁କରିବାରେ': 128704,
#  'edenis': 155095,
#  '▁दिएको': 170406,
#  '▁જવાબદારી': 176432,
#  '▁bikesa': 151530,
#  '▁دانید': 109833,
#  '▁تاقی': 84713,
#  '▁нәмә': 75431,
#  '▁мәҙәни': 123268,
#  'bwira': 172846,
#  '▁Sue': 74306,
#  'ཚོང་': 192541,
#  '▁његов': 125116,
#  '▁sutik': 176496,
#  '▁uniber': 177580,
#  '▁kiếm': 36627,
#  '▁మార్కెట్': 174215,
#  'ແຫຼ': 215070,
#  'вах': 26623,
#  '▁prinsipio': 235953,
#  'lakwika': 187712,
#  '▁לחלו': 177823,
#  'colta': 165976,
#  'itest': 211326,
#  '▁seth': 125460,
#  '▁talking': 71062,
#  '▁Ɛsɛ': 113654,
#  '▁ruka': 145355,
#  '▁보이': 67213,
#  '▁גרי': 116043,
#  'tidigt': 126054,
#  '▁Langu': 80935,
#  'inyenti': 75209,
#  '▁പ്രതീക്ഷ': 108948,
#  'မယ့်': 197987,
#  '▁sanadkii': 231326,
#  'њима': 111931,
#  'ናንተ': 71254,
#  '▁ру': 5969,
#  '▁ജൂ': 212809,
#  '▁досі': 208431,
#  'ຄຸນ': 144639,
#  'okoľvek': 123773,
#  'klāt': 67876,
#  '▁banis': 158733,
#  '▁ŵanga': 219660,
#  '▁indir': 68063,
#  '曜日': 81923,
#  '▁ٲ': 103007,
#  '▁chon': 92237,
#  '期間は': 242726,
#  'inei': 24312,
#  '▁kolmen': 234045,
#  'វត្ត': 103364,
#  '▁Polen': 138073,
#  'osele': 178790,
#  'ναν': 50390,
#  'örtön': 221814,
#  'vnt': 125937,
#  'گەندە': 98163,
#  '▁Palest': 36822,
#  '▁ɖés': 62735,
#  'もあります': 74057,
#  '▁ատ': 148096,
#  '▁lantai': 153289,
#  '▁Pawlu': 130845,
#  '▁유효': 159671,
#  'atanzwe': 228692,
#  '▁எழுது': 210424,
#  '▁үлд': 110691,
#  '▁१९': 43025,
#  '▁αργ': 98040,
#  'ที่ได้': 204998,
#  '▁편안': 94937,
#  '▁nǐ': 61533,
#  '/2006,': 200288,
#  '▁ձեւ': 86094,
#  '发展中': 96480,
#  'ሕግ': 67961,
#  'uther': 40010,
#  '▁منتظر': 114966,
#  'gó': 86159,
#  'ikidilu': 245451,
#  '▁રાજ્યો': 193499,
#  '▁Children': 90819,
#  '▁greičiau': 204659,
#  '▁ukũlĩhĩso': 153630,
#  '▁taikymo': 164009,
#  '▁enyi': 44965,
#  '▁giovani': 176881,
#  '▁సమావేశ': 164320,
#  '▁사람이다': 204227,
#  '▁umhlaba': 68596,
#  'šte': 16279,
#  'Yehowa': 74794,
#  '▁tey': 14869,
#  '▁kofanda': 112409,
#  '▁જૂથ': 130351,
#  '▁ଥରେ': 117237,
#  '▁ਸ਼ੈ': 242751,
#  'ाते': 42042,
#  '監督': 79732,
#  'mæssige': 113786,
#  'tsam': 198211,
#  'വണ': 89089,
#  '▁Ematshan': 128356,
#  '▁બિલ': 189318,
#  '▁hyödy': 223342,
#  '▁fale': 31319,
#  '▁calten': 117597,
#  'gidere': 205383,
#  'Nije': 228919,
#  '▁plekke': 212748,
#  '▁вакытта': 66833,
#  'zsm_Latn': 256125,
#  'ojë': 94827,
#  '▁kontemp': 238995,
#  'πέ': 43405,
#  '▁여성이': 142383,
#  '▁조언을': 183877,
#  'engeza': 176388,
#  '▁Per': 2424,
#  '▁مسلمانان': 227180,
#  '▁Мери': 226467,
#  'umak': 93957,
#  'tio': 14603,
#  '▁nza': 73040,
#  '▁pemikiran': 105154,
#  '▁yeku': 47180,
#  '▁kol': 3102,
#  'ġi': 5314,
#  '▁بالت': 78363,
#  'ayət': 95700,
#  '▁ଆବଶ୍ୟକତା': 121843,
#  '▁Thế': 74570,
#  '▁muru': 95346,
#  '▁નિ': 20209,
#  '▁Мӯсо': 232614,
#  '苦しみ': 177890,
#  '▁onwe': 20626,
#  'तपा': 197080,
#  '▁αυτόν': 77469,
#  'を満た': 116944,
#  '▁bied': 67636,
#  '▁шағын': 144098,
#  '▁dzis': 204729,
#  '▁यामुळे': 154160,
#  '▁해결할': 185951,
#  '▁Uqham': 106364,
#  '▁real': 12284,
#  '▁Además': 110404,
#  '▁dhawa': 198692,
#  '▁voljo': 82518,
#  'چاو': 84603,
#  '▁kwĩsĩla': 224664,
#  '▁종종': 47797,
#  '▁تۇي': 161821,
#  ...}

# %%
thai_char_min = 0x0E00
thai_char_max = 0x0E7F

thai_tokens = [
    token for token in tokenizer.vocab.keys()
    if any(thai_char_min <= ord(char) <= thai_char_max for char in token)
]

thai_token_count = len(thai_tokens)
sample_size = 20
thai_tokens_sample = thai_tokens[:sample_size]


print(f"{thai_token_count}\n")
for token in thai_tokens_sample:
  print(token)

# %%
import tensorflow as tf
import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots
import numpy as np
import math

# %%
sentence = 'Work hard, play harder'

# %%
cleaned_sentence = sentence.replace(',', '')
cleaned_sentence
# Out:
# 'Work hard play harder'

# %%
words = cleaned_sentence.split()
words
# Out:
# ['Work', 'hard', 'play', 'harder']

# %%
sorted_words = sorted(words)
sorted_words
# Out:
# ['Work', 'hard', 'harder', 'play']

# %%
dc = {word: index for index, word in enumerate(sorted_words)}
dc
# Out:
# {'Work': 0, 'hard': 1, 'harder': 2, 'play': 3}

# %%
sentence_int = tf.constant(
    [dc[s] for s in sentence.replace(',', '').split()],
    dtype=tf.int32
)

# %%
print(sentence)
print(sentence_int)
# Out:
# Work hard, play harder
# tf.Tensor([0 1 3 2], shape=(4,), dtype=int32)

# %%
# สร้าง embedding layer
tf.random.set_seed(123)
vocab_size = 50_000
embedding_dim = 2

embed = tf.keras.layers.Embedding(input_dim=vocab_size, output_dim=embedding_dim)

# %%
embedded_sentence = embed(sentence_int)

# %%
embedded_sentence
# Out:
# <tf.Tensor: shape=(4, 2), dtype=float32, numpy=
# array([[ 0.0034201 ,  0.04288404],
#        [ 0.00715679, -0.03252377],
#        [-0.01708775, -0.00808929],
#        [-0.03831335, -0.0052387 ]], dtype=float32)>

# %%
tf.random.set_seed(123)
vocab_size = 50_000
embedding_dim = 2

dummy_input = tf.constant([0, 1, 2], dtype=tf.int32)

# Case 1 Default initializer (RandomUniform(-0.05, 0.05))
embed_default = tf.keras.layers.Embedding(input_dim=vocab_size, output_dim=embedding_dim)
_ = embed_default(dummy_input) # เรียกใช้งาน layer เพื่อสร้าง weights
weights_default = embed_default.get_weights()[0].flatten()
weights_default.shape
# Out:
# (100000,)

# %%
# Case 2 GlorotUniform initializer
tf.random.set_seed(123)
embed_glorot = tf.keras.layers.Embedding(
    input_dim=vocab_size,
    output_dim=embedding_dim,
    embeddings_initializer=tf.keras.initializers.GlorotUniform()
)
_ = embed_glorot(dummy_input) # เรียกใช้งาน layer เพื่อสร้าง weights
weights_glorot = embed_glorot.get_weights()[0].flatten()
weights_glorot.shape
# Out:
# (100000,)

# %%
fig = make_subplots(rows=1, cols=1)

fig.add_trace(go.Histogram(x=weights_default, nbinsx=50, name="Default Uniform [-0.05, 0.05]", opacity=0.6))
fig.add_trace(go.Histogram(x=weights_glorot, nbinsx=50, name="Glorot Uniform", opacity=0.6))

fig.update_layout(
    title_text='Embedding Layer Initialization Comparison',
    xaxis_title_text='Weight values',
    yaxis_title_text='Frequency',
    barmode='overlay',
    legend_orientation="h",
    legend_yanchor="bottom",
    legend_y=1.02,
    legend_xanchor="right",
    legend_x=1
)

fig.show()

print("Default initializer range ", weights_default.min(), weights_default.max())
print("Glorot initializer range ", weights_glorot.min(), weights_glorot.max())
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="54c1381f-8e13-437f-874d-8716ac50cd87" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("54c1381f-8e13-437f-874d-8716ac50cd87")) {                    Plotly.newPlot(                        "54c1381f-8e13-437f-874d-8716ac50cd87",                        [{"name":"Default Uniform [-0.05, 0.05]","nbinsx":50,"opacity":0.6,"x":[0.009269118,0.0060318485,-0.004815746,-0.018623661,-0.023392214,0.0012856945,0.026087094,-0.022409929,0.024499822,-0.021137668,0.03705443,-0.010381497,-0.03524089,-0.02493968,-0.004873287,0.03526901,0.038875762,0.046519447,-0.018003117,0.046348464,-0.0462178,-0.0031430237,0.04681815,-0.0049596913,-0.039826106,0.038762633,0.042524848,0.008585583,0.025048602,-0.04963038,0.023742918,-0.02669902,-0.037940957,-0.02576983,0.015621427,0.04231954,-0.033975482,-0.017450284,-0.02129581,-0.030555928,0.041850295,-0.03751757,-0.012110375,-0.01487105,-0.047632813,-0.0152153745,0.040757705,-0.04900813,-0.01259644,-0.024907721,-0.023031224,0.009734809,-0.011620652,0.047470298,0.013999108,-0.04870957,-0.000761617,0.007588029,0.022728268,-0.018181145,0.0065954924,0.020545792,-0.026666677,-0.030509723,-0.026087785,-0.0050107725,0.007703267,-0.006649174,0.042225245,0.04116342,-0.01909622,-0.035778236,-0.03836273,0.04986647,-0.015549697,-0.047361195,0.00359907,-0.0051729307,0.036633227,0.02582172,-0.018185724,0.03212956,0.016050626,0.006781865,-0.016799938,0.039340187,-0.028761579,0.030402493,0.03666464,0.044674303,0.028665233,0.02406137,0.04468851,-0.04818448,0.029838968,-0.0040036924,-0.00999967,-0.006093275,0.018120479,0.011050142,-0.018279828,0.004209839,0.026342783,0.025091562,0.030412916,-0.008596659,-0.035690557,-0.017259788,-0.0056164376,-0.012494922,-0.043091036,-0.022866512,-0.018175006,0.009130992,0.019854818,-0.044923913,-0.005538713,-0.03834374,-0.024454905,0.031342197,-0.0063570626,0.04563519,-0.039707817,0.0051410794,0.0009309426,-0.033461705,-0.041511856,0.03847209,0.04316983,-0.048804533,-0.046705592,-0.037078716,0.039749313,0.04201695,-0.0478384,0.007972468,-0.00890087,-0.029825186,-0.017265044,-0.020872438,0.0043489113,0.01616421,-0.0048893914,-0.029965937,0.03358123,0.04555906,0.036198232,0.016383674,-0.014729809,-0.02409562,-0.03536141,-0.019217372,-0.019706547,0.00991267,0.022011306,0.023457278,0.047560524,0.036698353,-0.04769106,0.019837711,-0.030401504,-0.011415876,-0.010761403,0.009881139,0.037554357,-0.017590322,0.04714178,0.033787217,0.046248402,0.04558647,0.018056918,0.0027253404,-0.017934538,-0.045199003,0.026701536,-0.0022768602,0.024063256,-0.048303116,-0.040442683,0.01848415,0.04869416,0.013586294,-0.033347845,-0.02484404,0.016471457,0.038851414,0.0348246,0.03973445,0.04721408,0.040079746,-0.042139553,-0.020652879,0.03447217,0.02334753,-0.04819665,0.0047419555,0.041512977,0.016025212,0.037044737,-0.02653687,-0.012392234,0.025423657,0.009620808,0.0385458,0.03263903,-0.040969003,0.041492615,0.044565324,-0.03991902,0.0031853095,0.038653042,0.0088508725,-0.012326501,-0.011334099,-0.004996311,0.030825604,-0.023312045,0.0038213357,-0.011040259,0.017790232,-0.025276184,0.04324091,-0.046913005,0.009655584,0.016564552,0.042552996,0.02800918,-0.022601772,0.03360187,-0.043134153,0.0014158003,-0.048028994,0.049395148,-0.008728754,0.0017567761,0.034867946,-0.027953029,-0.017322432,0.009554971,-0.04031253,0.04907388,0.016530763,-0.014466263,0.046720732,0.010658812,-0.01926278,0.016750265,0.04113939,0.011041928,-0.037929248,0.046427015,-0.020209229,-0.022415733,-0.02949134,-0.046207406,-0.02312013,-0.04956913,0.0120746605,0.03892752,0.032549087,0.016855206,0.02030364,-0.032338336,-0.03327197,-0.025629794,0.030166578,-0.00821824,-0.013783634,0.0011052489,-0.007824779,-0.02979517,0.044169273,-0.04110707,0.0133 ...
# Default initializer range  -0.049999546 0.04999924
# Glorot initializer range  -0.010954151 0.010954126

# %%
def glorot_uniform_limits(fan_in, fan_out):
    limit = math.sqrt(6.0 / (fan_in + fan_out))
    a, b = -limit, limit
    return a, b

# ตัวอย่าง Embedding layer (vocab_size=50000, embedding_dim=2)
fan_in = 50000
fan_out = 2

a, b = glorot_uniform_limits(fan_in, fan_out)
print("Glorot Uniform a =", a)
print("Glorot Uniform b =", b)
# Out:
# Glorot Uniform a = -0.010954232067652772
# Glorot Uniform b = 0.010954232067652772

# %%
model = AutoModelForSeq2SeqLM.from_pretrained(checkpoint)
# Out:
# config.json:   0%|          | 0.00/846 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/2.46G [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.46G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/189 [00:00<?, ?B/s]

# %%
token_embedding_layer = model.model.encoder.embed_tokens
token_embedding_layer.weight.shape
# Out:
# torch.Size([256206, 1024])

# %%
long_sentence = "In the vast realm of natural language processing, understanding the nuances of how models handle sequential data is crucial. Positional encoding plays a vital role in providing this essential information to the model, allowing it to differentiate between words at different positions in a sentence, which is fundamental for tasks like translation, summarization, and text generation."

# %%
tokens = tokenizer(long_sentence, return_tensors="pt")

print(tokens['input_ids'][0])
# Out:
# tensor([256047,    717,    349,  14430,  12284, 248070,    452,  25307,  65445,
#         157278, 248079, 133930,    349,    713,  75831,    452,  11657, 141057,
#          47274, 116914, 124785,   6067,    248, 182071, 248075,  12013,  58409,
#          12025, 246156,   3054,    705,      9, 104781,  76065,    108, 174693,
#           3423, 140515,  18781,    202,    349,  14916, 248079,  82935,     87,
#            796,    202,  53054,    502,  25914,  51744,    230,  30158, 199073,
#            108,      9, 109267, 248079,   9089,    248,  75529,    351, 226047,
#           6399, 200356, 248079,   2493, 109207, 181953, 248079,    540,  35883,
#         120531, 248075,      2])

# %%
len(tokens['input_ids'][0])
# Out:
# 75

# %%
token_embedding_layer(tokens['input_ids'][0][0]).shape
# Out:
# torch.Size([1024])

# %%
token_embeddings = token_embedding_layer(tokens['input_ids'][0])

print("Token Embedding Matrix shape", token_embeddings.shape)
token_embeddings
# Out:
# Token Embedding Matrix shape torch.Size([75, 1024])
# tensor([[-5.0000e+00, -1.2725e+00, -9.3604e-01,  ..., -1.8297e+01,
#          -9.1328e+00, -1.0672e+01],
#         [ 2.6416e-01,  2.6831e-01,  2.0117e-01,  ...,  3.2715e+00,
#          -3.2402e+00,  3.1738e+00],
#         [ 4.3579e-01, -2.3352e-01,  2.6825e-02,  ...,  5.4648e+00,
#           2.7129e+00,  5.5430e+00],
#         ...,
#         [ 8.5859e+00, -4.5391e+00, -4.7314e-01,  ..., -7.9529e-02,
#           7.4844e+00, -7.5156e+00],
#         [-2.4863e+00, -2.7515e-01,  5.6114e-03,  ...,  1.0180e+01,
#          -7.2422e+00, -4.8047e+00],
#         [-7.8320e-01, -9.0527e-01, -9.4482e-01,  ...,  3.1078e+01,
#          -8.1494e-01, -8.7354e-01]], grad_fn=<MulBackward0>)

# %%
import plotly.express as px

token_embeddings_np = token_embeddings.detach().numpy()

fig = px.imshow(
    token_embeddings_np,
    color_continuous_scale="RdBu",
    labels=dict(x="Embedding Dimension", y="Token Index", color="Value"),
    title="Token Embedding Heatmap"
)

fig.update_xaxes(side="top")
fig.update_layout(height=500, width=900)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="8068e25b-252d-4807-bfd9-fab4a701fb42" class="plotly-graph-div" style="height:500px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8068e25b-252d-4807-bfd9-fab4a701fb42")) {                    Plotly.newPlot(                        "8068e25b-252d-4807-bfd9-fab4a701fb42",                        [{"coloraxis":"coloraxis","name":"0","z":[[-5.0,-1.2724609,-0.93603516,-0.83203125,-2.8164062,-1.4824219,-1.4541016,-1.5322266,-2.0976562,-1.3632812,-1.3916016,-0.8466797,-0.40673828,-2.1171875,-2.9785156,-5.9257812,-3.2480469,-3.2265625,-5.4296875,-4.6445312,-4.6210938,-2.7578125,1.6699219,0.23669434,2.6699219,0.6894531,2.1640625,-1.4003906,-1.5332031,1.078125,0.27319336,-0.044677734,-4.484375,2.7148438,-0.82714844,-0.9248047,-1.4833984,1.5966797,0.3942871,2.7675781,-0.18151855,-1.4208984,1.4765625,-3.5234375,-1.9033203,-0.36523438,-3.0449219,-7.0078125,3.3378906,-2.4453125,-1.21875,0.6464844,-0.20788574,0.50927734,-0.35546875,2.6171875,-1.484375,-7.21875,-1.6210938,-4.1679688,-6.3476562,0.6245117,-0.8540039,-0.36621094,0.53759766,-4.03125,-1.4160156,-1.6035156,-0.20056152,-2.6367188,0.5800781,-4.2421875,-1.0517578,1.6572266,-3.7011719,-2.1425781,-2.3203125,-0.46142578,-3.1484375,-3.5039062,5.1484375,1.5410156,-2.4667969,1.8359375,-0.8930664,1.2636719,-2.5976562,1.8720703,-1.9160156,1.6894531,-0.9248047,-3.6503906,-2.6464844,3.9433594,-1.8027344,0.08276367,-2.3632812,-0.3720703,-1.2607422,-1.0986328,0.82666016,-2.9101562,-0.7949219,3.4023438,3.4804688,-5.0664062,1.2001953,-2.8222656,-0.0925293,-0.06573486,-4.15625,-0.24804688,-5.2421875,-5.2070312,-1.1210938,-2.1269531,-0.9296875,1.3291016,0.5756836,3.2910156,0.028930664,-3.2949219,-0.74902344,1.9746094,3.2324219,-2.9824219,-4.078125,2.9355469,-0.37890625,-6.0429688,-1.1982422,5.2929688,-0.9555664,-1.0087891,-2.4609375,-2.8320312,7.0390625,1.34375,6.0195312,-4.3007812,-0.33691406,1.3554688,1.9746094,0.88964844,-0.8432617,-1.1689453,2.0429688,-3.375,-2.2167969,-1.0732422,-6.8984375,5.59375,0.70751953,-2.4511719,1.0996094,2.953125,1.5742188,0.7495117,-4.53125,-2.7207031,2.3007812,0.19958496,1.5048828,-2.625,4.9140625,1.2363281,-1.4033203,-0.7739258,2.9023438,-1.9794922,0.5097656,-5.03125,4.3164062,-1.4628906,-3.6289062,7.9023438,-5.4101562,-0.79541016,1.2724609,-3.03125,-3.2617188,-0.7285156,9.453125,6.8710938,-0.78027344,0.8461914,-0.028656006,-1.4453125,-0.89697266,0.20361328,-5.5234375,-3.1992188,0.09460449,5.4921875,-2.9335938,5.6484375,0.92285156,2.1542969,-3.6738281,-2.5722656,-5.1953125,-4.4296875,6.0625,2.1171875,-0.19140625,2.3886719,-2.3144531,-1.4082031,1.1728516,9.0859375,-5.3789062,-0.14526367,-3.1972656,1.8076172,0.8041992,2.4199219,-0.009849548,-6.2070312,-1.6171875,-3.8027344,2.0898438,-2.5351562,0.86816406,0.17224121,-0.5800781,3.7070312,1.9980469,5.015625,-1.7001953,-0.2734375,-1.4921875,3.2675781,-1.4570312,-3.8964844,-1.7021484,-5.0351562,2.5410156,-4.4414062,-2.9394531,9.359375,-0.703125,-0.5439453,-11.515625,4.1367188,6.640625,2.7636719,-2.6054688,-0.5625,1.6259766,0.94140625,0.2746582,0.24401855,-5.3671875,4.6367188,-5.25,6.1484375,-5.5429688,-0.3149414,-2.1875,-2.0859375,-1.1806641,7.3671875,-0.17993164,-1.1494141,-15.9296875,-1.5449219,-3.7226562,-4.6484375,3.0507812,5.1835938,-2.4550781,3.71875,-0.9057617,8.40625,0.1361084,-4.65625,3.203125,0.28466797,-7.28125,-2.9941406,-5.0625,0.92578125,-12.6796875,-5.2929688,0.47802734,18.0625,-11.078125,3.34375,-3.3222656,0.3605957,-6.3164062,-17.1875,3.6796875,-4.4257812,-8.4375,-6.2578125,16.046875,-4.4570312,0.10467529,0.18127441,-4.0664062,-0.4375,1.3125,-1.5859375,-3.6503906,-5.1875,0.32910156,-3.6367188,-3.1835938,-1.5380859,-2.1601562,2.2910156,2.0507812,4.1367188,3.1503906,-0.33325195,-0.03668213,0.8671875,-2.8515625,-7.3359375,-2.9296875,-4.6015625,0.0 ...

# %%
d = embedded_sentence.shape[-1]
d
# Out:
# 2

# %%
d_q, d_k, d_v = 2, 2, 4

d_q, d_k, d_v
# Out:
# (2, 2, 4)

# %%
tf.random.set_seed(123)
W_query = tf.Variable(tf.random.uniform((d, d_q)), trainable=True)
W_key   = tf.Variable(tf.random.uniform((d, d_k)), trainable=True)
W_value = tf.Variable(tf.random.uniform((d, d_v)), trainable=True)

# %%
print(W_query.shape, W_key.shape, W_value.shape)
# Out:
# (2, 2) (2, 2) (2, 4)

# %%
W_query
# Out:
# <tf.Variable 'Variable:0' shape=(2, 2) dtype=float32, numpy=
# array([[0.12615311, 0.5727513 ],
#        [0.2993133 , 0.5461836 ]], dtype=float32)>

# %%
W_key
# Out:
# <tf.Variable 'Variable:0' shape=(2, 2) dtype=float32, numpy=
# array([[0.88968754, 0.12354946],
#        [0.7718717 , 0.6850728 ]], dtype=float32)>

# %%
W_value
# Out:
# <tf.Variable 'Variable:0' shape=(2, 4) dtype=float32, numpy=
# array([[0.48962688, 0.5857923 , 0.36451697, 0.6550509 ],
#        [0.9075084 , 0.37557673, 0.6882372 , 0.25384045]], dtype=float32)>

# %%
embedded_sentence
# Out:
# <tf.Tensor: shape=(4, 2), dtype=float32, numpy=
# array([[ 0.0034201 ,  0.04288404],
#        [ 0.00715679, -0.03252377],
#        [-0.01708775, -0.00808929],
#        [-0.03831335, -0.0052387 ]], dtype=float32)>

# %%
queries = tf.matmul(embedded_sentence, W_query)
keys    = tf.matmul(embedded_sentence, W_key)
values  = tf.matmul(embedded_sentence, W_value)

# %%
print("Queries shape", queries.shape)
queries
# Out:
# Queries shape (4, 2)
# <tf.Tensor: shape=(4, 2), dtype=float32, numpy=
# array([[ 0.01326722,  0.02538143],
#        [-0.00883195, -0.01366489],
#        [-0.00457691, -0.01420527],
#        [-0.00640136, -0.02480531]], dtype=float32)>

# %%
print("Keys shape", keys.shape)
keys
# Out:
# Keys shape (4, 2)
# <tf.Tensor: shape=(4, 2), dtype=float32, numpy=
# array([[ 0.0361438 ,  0.02980124],
#        [-0.01873687, -0.02139693],
#        [-0.02144665, -0.00765294],
#        [-0.03813052, -0.00832248]], dtype=float32)>

# %%
print("Values shape", values.shape)
values
# Out:
# Values shape (4, 4)
# <tf.Tensor: shape=(4, 4), dtype=float32, numpy=
# array([[ 0.0405922 ,  0.01810972,  0.03076108,  0.01312605],
#        [-0.02601144, -0.00802278, -0.0197753 , -0.00356779],
#        [-0.01570772, -0.01304802, -0.01179613, -0.01324673],
#        [-0.02351341, -0.0244112 , -0.01757134, -0.02642699]],
#       dtype=float32)>

# %%
omega = tf.matmul(queries, keys, transpose_b=True)

print("Omega shape", omega.shape)
print("Omega (Unnormalized attention weights)")
print(omega)
# Out:
# Omega shape (4, 4)
# Omega (Unnormalized attention weights)
# tf.Tensor(
# [[ 0.00123593 -0.00079167 -0.00047878 -0.00071712]
#  [-0.00072645  0.00045787  0.00029399  0.00045049]
#  [-0.00058876  0.00038971  0.00020687  0.00029274]
#  [-0.0009706   0.0006507   0.00032712  0.00045053]], shape=(4, 4), dtype=float32)

# %%
d_k = tf.cast(d_k, tf.float32)

scaled_omega = omega / tf.sqrt(d_k)

attention_weights = tf.nn.softmax(scaled_omega, axis=-1)

print("Attention Weights")
print(attention_weights)
# Out:
# Attention Weights
# tf.Tensor(
# [[0.2502518  0.24989325 0.24994855 0.24990642]
#  [0.24985059 0.2500599  0.25003093 0.2500586 ]
#  [0.24988265 0.2500556  0.25002328 0.25003847]
#  [0.24980824 0.2500948  0.25003758 0.2500594 ]], shape=(4, 4), dtype=float32)

# %%
row_sums = tf.reduce_sum(attention_weights, axis=-1)

print("Sum of each row in attention_weights")
row_sums
# Out:
# Sum of each row in attention_weights
# <tf.Tensor: shape=(4,), dtype=float32, numpy=array([1., 1., 1., 1.], dtype=float32)>

# %%
context_vector = tf.matmul(attention_weights, values)

print("Context Vector shape", context_vector.shape)
print(context_vector)
# Out:
# Context Vector shape (4, 4)
# tf.Tensor(
# [[-0.00614409 -0.0068347  -0.00458331 -0.00752203]
#  [-0.00616958 -0.00684809 -0.0046026  -0.007533  ]
#  [-0.00616757 -0.00684689 -0.00460108 -0.00753193]
#  [-0.00617233 -0.00684925 -0.00460468 -0.00753379]], shape=(4, 4), dtype=float32)

# %%
class SelfAttention(tf.keras.layers.Layer):
    def __init__(self, d_in, d_out_kq, d_out_v):
        super().__init__()
        self.d_out_kq = d_out_kq

        self.W_query = tf.Variable(
            tf.random.uniform((d_in, d_out_kq)), trainable=True
        )
        self.W_key = tf.Variable(
            tf.random.uniform((d_in, d_out_kq)), trainable=True
        )
        self.W_value = tf.Variable(
            tf.random.uniform((d_in, d_out_v)), trainable=True
        )

    def call(self, x):
        keys = tf.matmul(x, self.W_key)      # [T, d_out_kq]
        queries = tf.matmul(x, self.W_query) # [T, d_out_kq]
        values = tf.matmul(x, self.W_value)  # [T, d_out_v]

        # Attention scores: QKᵀ
        attn_scores = tf.matmul(queries, keys, transpose_b=True)  # [T, T]

        # Softmax (scaled by sqrt(d_k))
        attn_weights = tf.nn.softmax(
            attn_scores / tf.math.sqrt(tf.cast(self.d_out_kq, tf.float32)), axis=-1
        )  # [T, T]

        # Weighted sum
        context_vec = tf.matmul(attn_weights, values)  # [T, d_out_v]
        return context_vec

# %%
tf.random.set_seed(123)

d_in, d_out_kq, d_out_v = 2, 2, 4

sa = SelfAttention(d_in, d_out_kq, d_out_v)

out = sa(embedded_sentence)

print(out.shape)  # (T, d_out_v)
print(out.numpy())
# Out:
# (4, 4)
# [[-0.00614409 -0.0068347  -0.00458331 -0.00752203]
#  [-0.00616958 -0.00684809 -0.0046026  -0.007533  ]
#  [-0.00616757 -0.00684689 -0.00460108 -0.00753193]
#  [-0.00617233 -0.00684925 -0.00460468 -0.00753379]]

# %%
class MultiHeadAttentionWrapper(tf.keras.layers.Layer):
    def __init__(self, d_in, d_out_kq, d_out_v, num_heads):
        super().__init__()
        self.heads = [
            SelfAttention(d_in, d_out_kq, d_out_v)
            for _ in range(num_heads)
        ]

    def call(self, x):
        # รันทุก head แล้ว concat ตามแกนสุดท้าย
        head_outputs = [head(x) for head in self.heads]   # list of [T, d_out_v]
        return tf.concat(head_outputs, axis=-1)           # [T, num_heads * d_out_v]

# %%
tf.random.set_seed(123)

d_in, d_out_kq, d_out_v = 2, 2, 1

sa = SelfAttention(d_in, d_out_kq, d_out_v)

# ถ้า embedded_sentence.shape = [T, d_in] เช่น [6, 3]
out = sa(embedded_sentence)

print(out.shape)   # (T, d_out_v) -> (6, 1)
print(out.numpy())
# Out:
# (4, 1)
# [[-0.00591028]
#  [-0.00592802]
#  [-0.00592656]
#  [-0.0059298 ]]

# %%
tf.random.set_seed(123)

mha = MultiHeadAttentionWrapper(
    d_in, d_out_kq, d_out_v, num_heads=3
)

# run MHA
context_vecs = mha(embedded_sentence)   # [T, num_heads * d_out_v]

print(context_vecs)
print("context_vecs.shape:", context_vecs.shape)
# Out:
# tf.Tensor(
# [[-0.00591028 -0.00624067 -0.00892885]
#  [-0.00592802 -0.00625105 -0.00893466]
#  [-0.00592656 -0.0062518  -0.00894402]
#  [-0.0059298  -0.00625517 -0.00895409]], shape=(4, 3), dtype=float32)
# context_vecs.shape: (4, 3)
